# %%
D[D[ArcTan[x y], x], x]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
D[ArcTan[x y], {x, 2}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
D[ArcTan[x y], {y, 2}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
Simplify[D[ArcTan[x y], {x, 2}] + D[ArcTan[x y], {y, 2}]]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
Simplify[D[Exp[x] (Sin[y] + Cos[y]), {x, 2}] + D[Exp[x] (Sin[y] + Cos[y]), {y, 2}]]
# Out:
# <div><pre style="&#102;&#111;&#110;&#116;&#45;&#102;&#97;&#109;&#105;&#108;&#121;&#58;&#32;&#34;&#67;&#111;&#117;&#114;&#105;&#101;&#114;&#32;&#78;&#101;&#119;&#34;&#44;&#67;&#111;&#117;&#114;&#105;&#101;&#114;&#44;&#109;&#111;&#110;&#111;&#115;&#112;&#97;&#99;&#101;&#59;">&#48;</pre></div>

# %%
Simplify[D[x y / (x^2 + y^2), x]]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
D[-y (x^2 - y^2) / (x^2 + y^2)^2, x]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
D[x (x^2 - y^2) / (x^2 + y^2)^2, y]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
GeoGraphics["Tokyo"]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
WolframAlpha["plot a sine curve"]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
D[Exp[Abs[x] + Abs[y]], x]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
f[x_, y_] := 0 /; x == 0 && y == 0
f[x_, y_] := x y Sin[1 / Sqrt[x^2 + y^2]] /; x != 0 || y != 0
Dt[f[x, y]]
# Out:
# <div><pre style="&#102;&#111;&#110;&#116;&#45;&#102;&#97;&#109;&#105;&#108;&#121;&#58;&#32;&#34;&#67;&#111;&#117;&#114;&#105;&#101;&#114;&#32;&#78;&#101;&#119;&#34;&#44;&#67;&#111;&#117;&#114;&#105;&#101;&#114;&#44;&#109;&#111;&#110;&#111;&#115;&#112;&#97;&#99;&#101;&#59;">&#48;</pre></div>

# %%
ContourPlot[(x - 1)^2 + y^2, {x, -2, 2}, {y, -2, 2}, ContourShading -> None]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>
